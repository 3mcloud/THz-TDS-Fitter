# %%
import thzfitter.thzfitter as fit
import thzfitter.fitgui as gui
# %matplotlib notebook  # use for jupyter nbclassic
# %matplotlib widget  # use for jupyter lab
output = gui.wdg.Output()
fitter = fit.THzFitter()
UI = gui.FitterGUI(fitter, output)
UI.display()
# Out:
# <img src="data:image/png;base64,..." width="949.3333333333334">
# ...
# Output()
